# %%
from ultralytics import YOLO

model_path = "/home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/train15/weights/best.onnx" 
data_yaml = "data_2.yaml"

model = YOLO(model_path, task="detect")
metrics = model.val(data=data_yaml, imgsz=1280) 

print(metrics)
# Out:
# Ultralytics 8.3.161 🚀 Python-3.10.12 torch-2.7.1+cu126 CUDA:0 (NVIDIA RTX A5000, 24248MiB)
# Loading /home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/train15/weights/best.onnx for ONNX Runtime inference...
# Using ONNX Runtime CUDAExecutionProvider
# Setting batch=1 input of shape (1, 3, 1280, 1280)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 7279.5±4085.2 MB/s, size: 2169.0 KB)
# 2025-07-04 09:38:06.050889248 [W:onnxruntime:, transformer_memcpy.cc:83 ApplyImpl] 4 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# val: Scanning /home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/dataset/labels/valid.cache... 500 images, 102 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
# ...

# %%
from ultralytics import YOLO

model_path = "/home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/quantized_models/best_quant_QUInt8.onnx" 

data_yaml = "data_2.yaml"

model = YOLO(model_path, task="detect")
metrics = model.val(data=data_yaml, imgsz=1280)  

print(metrics)
# Out:
# Ultralytics 8.3.161 🚀 Python-3.10.12 torch-2.7.1+cu126 CUDA:0 (NVIDIA RTX A5000, 24248MiB)
# Loading /home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/quantized_models/best_quant_QUInt8.onnx for ONNX Runtime inference...
# Using ONNX Runtime CUDAExecutionProvider
# Setting batch=1 input of shape (1, 3, 1280, 1280)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 10696.1±750.6 MB/s, size: 2193.4 KB)
# 2025-07-04 09:39:46.506323022 [W:onnxruntime:, transformer_memcpy.cc:83 ApplyImpl] 316 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# val: Scanning /home/dll1305/Documents/ai-project/tf_models/object_detection/quantization/AI_Project/dataset/labels/valid.cache... 500 images, 102 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
# ...
